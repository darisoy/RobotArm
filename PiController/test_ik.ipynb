# %%
import ikpy
import numpy as np
from ikpy import plot_utils

my_chain = ikpy.chain.Chain.from_urdf_file("./ik/niryo_one.urdf")

# %%
target_vector = [ 0.4, 0.4, 0.4]
target_frame = np.eye(4)
target_frame[:3, 3] = target_vector

angles = my_chain.inverse_kinematics(target_frame)
print("angles: ", np.degrees(angles[:7]))
# print("The angles of each joints are :")
# for i in range(len(angles)):
#     print(angles[i] * 180 / np.pi)

real_frame = my_chain.forward_kinematics(angles)
print("Computed position vector : %s, original position vector : %s" % (real_frame[:3, 3], target_frame[:3, 3]))

# %matplotlib notebook
import matplotlib.pyplot as plt
ax = plot_utils.init_3d_figure()
my_chain.plot(my_chain.inverse_kinematics(target_frame), ax, target=target_vector)
plt.xlim(-0.5, 0.5)
plt.ylim(-0.5, 0.5)
# Out:
# angles:  [  0.          45.02463643 -69.01268152  82.28865596   3.2044002
#   20.76604837   0.        ]
# Computed position vector : [0.30227172 0.30227394 0.34698262], original position vector : [0.4 0.4 0.4]
# <img src="data:image/png;base64,..." width="640">
# (-0.5, 0.5)
